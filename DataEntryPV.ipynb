# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datapv = pd.read_csv('Data/ninja_pv_52.5170_13.3889_corrected.csv', index_col = 0)
datapv
# Out:
#                         local_time  electricity  missing
# time
# 2014-01-01 00:00  2014-01-01 01:00          0.0        0
# 2014-01-01 01:00  2014-01-01 02:00          0.0        0
# 2014-01-01 02:00  2014-01-01 03:00          0.0        0
# 2014-01-01 03:00  2014-01-01 04:00          0.0        0
# 2014-01-01 04:00  2014-01-01 05:00          0.0        0
# ...                            ...          ...      ...
# 2014-12-31 19:00  2014-12-31 20:00          0.0        0
# 2014-12-31 20:00  2014-12-31 21:00          0.0        0
# 2014-12-31 21:00  2014-12-31 22:00          0.0        0
# 2014-12-31 22:00  2014-12-31 23:00          0.0        0
# 2014-12-31 23:00  2015-01-01 00:00          0.0        0
#
# [8760 rows x 3 columns]

# %%
plotdatajan = datapv.loc['2014-01-01 00:00':'2014-01-31 23:00']
plotdataaug = datapv.loc['2014-08-01 00:00':'2014-08-31 23:00']

# %% [markdown]
# August PV-Leistung

# %%
plt.figure(figsize = (12, 5))
#plotdatajan['electricity'].plot()
plotdataaug['electricity'].plot(color="orange")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Januar PV-Leistung

# %%
plt.figure(figsize = (12, 5))
plotdatajan['electricity'].plot()
#plotdataaug['electricity'].plot()
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Januar und August PV-Leistung übereinander

# %%
plt.figure(figsize = (12, 5))
plotdatajan['electricity'].plot()
plotdataaug['electricity'].plot()
plt.xticks(rotation=45)

plt.show()

# %%
datapv.describe()
# Out:
#        electricity  missing
# count  8760.000000   8760.0
# mean      0.125872      0.0
# std       0.207429      0.0
# min       0.000000      0.0
# 25%       0.000000      0.0
# 50%       0.000000      0.0
# 75%       0.174000      0.0
# max       0.878000      0.0

# %% [markdown]
# Jahresverlauf PV-Leistung

# %%
plt.figure(figsize = (12, 5))
datapv['electricity'].plot()

plt.xticks(rotation=45)

plt.show()
