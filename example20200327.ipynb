# %%
import Functions as func

# %%
datafcr, dataafrr, datamfrr, datalastprofile, pvdata = func.getdata('11-01','11-09')
func.plotdataframecontrolenergy(dataafrr, 'POS')
func.plotdataframecontrolenergy(dataafrr, 'NEG')
func.plotpvdata(pvdata)
func.plotlastprofiledata(datalastprofile, 72)
# datafcr['CROSSBORDER_SETTLEMENTCAPACITY_PRICE_[EUR/MW]'].plot()
