# %%
import Functions as func
import pandas as pd

# %%
datafcr, dataafrr, datamfrr, datalastprofile, pvdata, pricedata = func.getdata('01-10','01-20')
func.plotdataframecontrolenergy(dataafrr, 'POS')
func.plotdataframecontrolenergy(dataafrr, 'NEG')
func.plotpvdata(pvdata)
func.plotlastprofiledata(datalastprofile, [1, 2, 3, 4, 5, 6, 7, 8, 9, 72])
func.plotpricedata(pricedata)
func.plotprimecontroldata(datafcr)

# %%
indexlogdata = datalastprofile.index

# %%
indexlogdata
# Out:
# Index(['2014-11-01 00:00:00', '2014-11-01 00:15:00', '2014-11-01 00:30:00',
#        '2014-11-01 00:45:00', '2014-11-01 01:00:00', '2014-11-01 01:15:00',
#        '2014-11-01 01:30:00', '2014-11-01 01:45:00', '2014-11-01 02:00:00',
#        '2014-11-01 02:15:00',
#        ...
#        '2014-11-08 21:30:00', '2014-11-08 21:45:00', '2014-11-08 22:00:00',
#        '2014-11-08 22:15:00', '2014-11-08 22:30:00', '2014-11-08 22:45:00',
#        '2014-11-08 23:00:00', '2014-11-08 23:15:00', '2014-11-08 23:30:00',
#        '2014-11-08 23:45:00'],
#       dtype='object', name='time', length=768)
